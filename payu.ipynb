# %%
# Box 1: Imports and config

import csv
import pandas as pd
import os
from difflib import get_close_matches
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_ollama import OllamaEmbeddings, OllamaLLM
from langchain.chains import RetrievalQA
from langchain_community.document_loaders import PyMuPDFLoader

# --- Configuration ---

csv_files = [
    "knowledge/finance-llama2-1k.csv",
    "knowledge\Beliance_news_sentiment.csv",
    "knowledge\\all_stocks_5yr.csv"
    # add more CSV filenames here
]    # Your CSV knowledge base file
pdf_files = [
    "knowledge\Context and HRM_ Theory, Evidence, and Proposals_25_06_25_23_15_52.pdf",
    "knowledge/rehumanising.pdf",
    "knowledge\Fundamental of management.pdf",
    "knowledge\Principles of Economics_5.pdf",
    "knowledge\OO. Gregory Mankiw. Macroeconomics  9th edition.pdf",
    "knowledge\zq_reynolds_microeconomics_07.pdf",
    "knowledge\Transodapdf-converted.pdf","knowledge\FokMoney.pdf",
    "knowledge\TangKongtrust.pdf", 
    "knowledge\StockMarkeTVolatility_25_06_25_23_06_45.pdf"
    # add more PDF filenames here
] 

INPUT_QUESTIONS_FILE = "financial-analysis-agent/test.csv"
OUTPUT_SUBMISSION_FILE = "financial-analysis-agent\submission.csv"

ID_COLUMN = "id"
QUESTION_COLUMN = "query"
ANSWER_MODE = "abcd"  # or "rise"

LLM_MODEL = "scb10x/llama3.1-typhoon2-8b-instruct"
EMBED_MODEL = "nomic-embed-text"

print("Imports and config loaded.")
# Out:
# Imports and config loaded.

# %%
# Box 2: Load knowledge base, split text, embed, build vector DB

# === Load multiple CSV and PDF files ===

all_csv_docs = []
for file in csv_files:
    try:
        df = pd.read_csv(file)
        docs = [
            Document(page_content=str(row["text"]))
            for _, row in df.iterrows()
            if str(row["text"]).strip()
        ]
        all_csv_docs.extend(docs)
        print(f"Loaded {len(docs)} docs from {file}")
    except Exception as e:
        print(f"Failed to load CSV {file}: {e}")

all_pdf_docs = []
for file in pdf_files:
    try:
        loader = PyMuPDFLoader(file)
        pdf_docs = loader.load()
        all_pdf_docs.extend(pdf_docs)
        print(f"Loaded {len(pdf_docs)} docs from {file}")
    except Exception as e:
        print(f"Failed to load PDF {file}: {e}")

# Combine all docs
all_docs = all_csv_docs + all_pdf_docs
print(f"Total documents to process: {len(all_docs)}")

# Proceed with splitting, embedding, vector DB building as before:
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_chunks = splitter.split_documents(all_docs)
all_chunks = [chunk for chunk in all_chunks if chunk.page_content.strip()]

embedder = OllamaEmbeddings(model=EMBED_MODEL)
valid_chunks = []
for doc in all_chunks:
    try:
        vec = embedder.embed_query(doc.page_content)
        if vec:
            valid_chunks.append(doc)
    except Exception:
        continue

if not valid_chunks:
    raise RuntimeError("No valid chunks after embedding.")

vector_db = Chroma.from_documents(valid_chunks, embedding=embedder)
print(f"Vector DB created with {len(valid_chunks)} chunks.")
# Out:
# Loaded 1000 docs from knowledge/finance-llama2-1k.csv
# Failed to load CSV knowledge\Beliance_news_sentiment.csv: 'text'
# Failed to load CSV knowledge\all_stocks_5yr.csv: 'text'
# Loaded 17 docs from knowledge\Context and HRM_ Theory, Evidence, and Proposals_25_06_25_23_15_52.pdf
# Loaded 39 docs from knowledge/rehumanising.pdf
# Loaded 547 docs from knowledge\Fundamental of management.pdf
# Loaded 330 docs from knowledge\Principles of Economics_5.pdf
# Loaded 645 docs from knowledge\OO. Gregory Mankiw. Macroeconomics  9th edition.pdf
# Loaded 301 docs from knowledge\zq_reynolds_microeconomics_07.pdf
# Loaded 355 docs from knowledge\Transodapdf-converted.pdf
# Loaded 10 docs from knowledge\FokMoney.pdf
# Loaded 10 docs from knowledge\TangKongtrust.pdf
# Loaded 654 docs from knowledge\StockMarkeTVolatility_25_06_25_23_06_45.pdf
# Total documents to process: 3908
# Vector DB created with 13072 chunks.

# %%
# Box 3: Setup LLM and RetrievalQA chain

llm = OllamaLLM(model=LLM_MODEL)
agent = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vector_db.as_retriever()
)
print("LLM and QA chain ready.")
# Out:
# LLM and QA chain ready.

# %%
# Box 4: Define interactive query session function with fuzzy matching and smart save

def interactive_query_session(
    agent,
    test_csv_path,
    submission_csv_path,
    id_column="id",
    query_column="query",
    answer_mode="abcd"
):


    def detect_question_type(question: str) -> str:
        q = question.lower()
        has_abcd = any(opt in q for opt in [" a.", " a:", " b.", " b:", " c.", " c:", " d.", " d:"])
        has_rise_fall = "rise" in q or "fall" in q or "ขึ้น" in q or "ลง" in q

        if has_rise_fall and not has_abcd:
            return "rise"
        elif has_abcd:
            return "abcd"
        return "unknown"

    def postprocess(raw_answer, mode="abcd"):
        raw = raw_answer.strip().lower()

        if mode == "abcd":
            for ch in ["a", "b", "c", "d"]:
                if raw.startswith(ch + ":") or raw.startswith(ch + ".") or raw == ch:
                    return ch.upper()
        elif mode == "rise":
            if "rise" in raw:
                return "Rise"
            elif "fall" in raw:
                return "Fall"

        return raw_answer

    def save_answers_update(submission_file, new_results, id_col="id"):
        if os.path.exists(submission_file):
            df = pd.read_csv(submission_file)
        else:
            df = pd.DataFrame(columns=[id_col, "answer"])

        answers_dict = dict(zip(df[id_col], df["answer"]))
        for r in new_results:
            answers_dict[r[id_col]] = r["answer"]

        updated_df = pd.DataFrame([{id_col: k, "answer": v} for k, v in answers_dict.items()])
        updated_df.to_csv(submission_file, index=False)
        print(f"✅ Saved {len(new_results)} answers to {submission_file} (updated existing entries)")

    print("🟢 Interactive mode: Enter your queries one by one.")
    print("⏎ Press Enter without typing to finish.\n")

    try:
        with open(test_csv_path, encoding="utf-8") as f:
            reader = list(csv.DictReader(f))
            query_to_id = {row[query_column].strip(): row[id_column] for row in reader}
    except Exception as e:
        print(f"❌ Failed to read test file: {e}")
        return

    results = []

    while True:
        user_input = input("❓ Query: ").strip()
        if not user_input:
            break

        matches = get_close_matches(user_input, list(query_to_id.keys()), n=1, cutoff=0.7)
        if not matches:
            print("❌ No match found.\n")
            continue

        matched_query = matches[0]
        matched_id = query_to_id[matched_query]
        print(f"🔎 Matched: {matched_query} → ID: {matched_id}")

        answer_mode = detect_question_type(matched_query)

        try:
            raw_ans = agent.run(matched_query)
            answer = postprocess(raw_ans, answer_mode)
            results.append({id_column: matched_id, "answer": answer})
            print(f"✅ Answer: {answer}\n")
        except Exception as e:
            print(f"❌ Error: {e}\n")

    print(f"\n📊 Session finished. {len(results)} answers collected.")
    if results:
        choice = input("💾 Save answers to submission.csv? (y/n): ").strip().lower()
        if choice == "y":
            save_answers_update(submission_csv_path, results, id_col=id_column)
        else:
            print("⚠️ Answers discarded.")
    else:
        print("⚠️ No answers to save.")

# %%
# Box 5: Run interactive query session

interactive_query_session(
    agent=agent,
    test_csv_path=INPUT_QUESTIONS_FILE,
    submission_csv_path=OUTPUT_SUBMISSION_FILE,
    id_column=ID_COLUMN,
    query_column=QUESTION_COLUMN,
    answer_mode=ANSWER_MODE
)
# Out:
# 🟢 Interactive mode: Enter your queries one by one.
# ⏎ Press Enter without typing to finish.
# 🔎 Matched: Given the data and tweets, could you project whether the closing price of $intc will grow or shrink at 2018-01-23? Please specify either Rise or Fall.
# Context: date,open,high,low,close,adj-close,inc-5,inc-10,inc-15,inc-20,inc-25,inc-30
# 2018-01-08,-1.1,0.2,-1.7,0.0,0.0,1.0,2.2,2.7,1.3,0.6,0.5
# 2018-01-09,2.5,2.8,-0.3,-2.5,-2.5,2.2,4.1,5.2,3.9,3.1,2.9
# 2018-01-10,2.0,2.6,-0.1,-2.6,-2.6,3.5,6.0,7.4,6.5,5.6,5.5
# 2018-01-11,-1.4,0.4,-2.2,2.1,2.1,0.9,3.2,4.6,4.3,3.4,3.2
# 2018-01-12,0.5,0.8,-0.5,-0.4,-0.4,0.6,2.9,4.4,4.7,3.8,3.5
# 2018-01-16,1.0,1.5,-0.6,-0.2,-0.2,0.1,2.4,4.0,4.9,4.1,3.7
# 2018-01-17,-1.9,0.1,-2.0,2.9,2.9,-2.4,-1.0,0.8,2.0,1.2,0.7
# 2018-01-18,-0.2,0.6,-0.7,0.2,0.2,-1.7,-1.4,0.3,1.6,1.1,0.5
# 2018-01-19,-0.4,0.2,-1.3,0.8,0.8,-1.8,-2.0,-0.6,0.5,0.5,-0.2
# 2018-01-22,-2.1,0.1,-2.1,2.1,2.1,-2.7,-3.8,-2.7,-1.7,-1.4,-2.0
#
# 2018-01-08: rt AT_USER $t $vz $intc $fb $bac $ge $mu $amd $bac $gm $rig $baba $s $aapl $orcl $esv $jci $wu $t - highest volume strikes |$t $vz $intc $fb $bac $ge $mu $amd $bac $gm $rig $baba $s $aapl $orcl $esv $
# 2018-01-09: $btc $spx $nasdaq $djia $cac $dax $ftse $jpm $tsla $es_f $cl_f $gc_f $tlt $wmt $jnj $fb $googl $msft $intc $amd¡­ |intel reveals its smart home tech impact at ces $intc |rt AT_USER senators reed, kenn
# 2018-01-10: this value etf gained 22% in 2017  $aapl $ibm $intc  via AT_USER|$intc 5.7m ago: kirby mcinerney llp commences investigation on behalf of intel corporation investors |f u $intc i can't even play frick
# 2018-01-11: find xtra yield w/buy-write search $sbux $intc $spy $ge $ebio $bac $ziop $fit $watt $bp $watt $dust |rt AT_USER my 2017 swing-trading in review $study $teck $sq $baba $twtr $intc $splk $fdx #finance #
# 2018-01-12: they all tell u what they're doing? no?...... i'm shocked. $c $key $pnc $eufn $kbe $rtn $lmt $iivi $ktos $apa $slb¡­ |so bullish.... $intc |rt AT_USER fascinating look at #intel's 49-qubit superconduc
# 2018-01-13: that german-built aircraft, with 18 rotors positioned around a ring above its trim fuselage, is called the volocop¡­ |$intc respecting fib's  - opinions always welcome |short ratio of $simo is 9.31 at
# 2018-01-14: rt AT_USER from january 12, 2018 2:53 pm¨ufinnish firm, f-secure detects new intel security flaw $intc ¨u  ¨u¡­|from january 12, 2018 2:53 pm¨ufinnish firm, f-secure detects new intel security flaw $i
# 2018-01-15: $oled 196 per share. close to 10 bill market cap on 400 mill in forward revs. their strategic fab partner boe.¡­ |rt AT_USER #gigabyte brix gb-bxi7-5775 ultra compact #pc has an #intel i7 cpu - get on
# 2018-01-16: unusual options activity - 01.18.2018 - $dish $bac $snap $intc $pbr $low $schw $wynn $nflx $slb $aapl $twtr $amzn¡­ |get the latest ratings for $jpm $abbv $wgp $intc $icd in your inbox with marketbeat
# 2018-01-17: according to wsj: us gov expects $339b in repatriation taxes in 10-year span. firms with most dollars in¡­ |$intc negative news regarding chip flaw not created major drawdown this stock. compression c
# 2018-01-18: #methuselah would be proud. first growth in five years. muscle memory, shares decline after hours. $ibm $aapl $csco¡­ |sign up for profectus systems and beat the market $intc $wdc $stx $spy $qqq $dia
# 2018-01-19: $amd $intc $amzn |$amd $intc $amzn |rt AT_USER jim cramer mad money game plan  AT_USER AT_USER $hal $nflx $vz $pg $jnj $trv $ge $utx $swk $cat¡­|rt AT_USER earnings on tap next week: $ubs $nflx $hal $
# 2018-01-20: rt AT_USER your tech top 10 is headed by microsoft, intel: thomson reuters rankings - tech trader daily- AT_USER - $msft $intc h¡­|$amd busrt out of a darvas box on the $intc security chip news. not s
# 2018-01-22: $ge $nflx $aapl $fb $bac $baba $t $mu $amd $fcx $tsla $f $msft $hal $nvda $vz $amzn $intc $twtr $sq $c $wfc $ibm¡­ |$intc max pain=44.00. maturity=01/26/2018. #maxpain #options  | &lt;-- free video on
# Answer: → ID: bcca13bc-2675-4645-82cc-7e4c412ed294
# ✅ Answer: ggggg
#
#
# 📊 Session finished. 1 answers collected.
# ⚠️ Answers discarded.

# %%
# Batch answer all queries in test.csv with strict answer filtering

def run_batch_query(
    agent,
    test_csv_path,
    submission_csv_path,
    id_column="id",
    query_column="query",
    max_retries=3
):

    def detect_question_type(question: str) -> str:
        q = question.lower()
        has_abcd = any(opt in q for opt in [" a.", " a:", " b.", " b:", " c.", " c:", " d.", " d:"])
        has_rise_fall = "rise" in q or "fall" in q or "ขึ้น" in q or "ลง" in q
        if has_rise_fall and not has_abcd:
            return "rise"
        elif has_abcd:
            return "abcd"
        return "unknown"

    def postprocess(raw_answer, mode="abcd"):
        raw = raw_answer.strip().lower()
        if mode == "abcd":
            for ch in ["a", "b", "c", "d"]:
                if raw.startswith(ch + ":") or raw.startswith(ch + ".") or raw == ch:
                    return ch.upper()
        elif mode == "rise":
            if "rise" in raw:
                return "Rise"
            elif "fall" in raw:
                return "Fall"
        return ""

    def force_valid_answer(raw_ans, mode="abcd"):
        for _ in range(max_retries):
            answer = postprocess(raw_ans, mode)
            if answer in ["A", "B", "C", "D", "Rise", "Fall"]:
                return answer
            try:
                raw_ans = agent.run(raw_ans)
            except:
                break
        return postprocess(raw_ans[:1], mode)  # fallback to first char

    # Load test queries
    try:
        df = pd.read_csv(test_csv_path)
    except Exception as e:
        print(f"Failed to load {test_csv_path}: {e}")
        return

    results = []

    for i, row in df.iterrows():
        query = str(row[query_column]).strip()
        qid = row[id_column]
        mode = detect_question_type(query)
        print(f"[{i+1}/{len(df)}] QID={qid} Mode={mode}")

        try:
            raw_ans = agent.run(query)
            final_ans = force_valid_answer(raw_ans, mode)
            results.append({id_column: qid, "answer": final_ans})
            print(f"✅ Answer: {final_ans}\n")
        except Exception as e:
            print(f"❌ Error on QID {qid}: {e}\n")

    # Save to CSV
    if results:
        if os.path.exists(submission_csv_path):
            existing = pd.read_csv(submission_csv_path)
            results_dict = dict(zip(existing[id_column], existing["answer"]))
        else:
            results_dict = {}

        for r in results:
            results_dict[r[id_column]] = r["answer"]

        df_save = pd.DataFrame([{id_column: k, "answer": v} for k, v in results_dict.items()])
        df_save.to_csv(submission_csv_path, index=False)
        print(f"\n💾 Saved {len(results)} answers to {submission_csv_path}")
    else:
        print("⚠️ No answers collected.")

# %%
# --- Run it here ---
run_batch_query(
    agent=agent,
    test_csv_path=INPUT_QUESTIONS_FILE,
    submission_csv_path=OUTPUT_SUBMISSION_FILE,
    id_column=ID_COLUMN,
    query_column=QUESTION_COLUMN
)
# Out:
# 🟢 Processing 499 queries in batch...
# 🔎 ID 36deab86-cfd3-48b5-9bea-a36c1b0e63a8: Answer = C
# 🔎 ID 2b5bbd26-45e8-4768-ab8a-b5dc1d153ab7: Answer = B
# 🔎 ID 8a722080-bc16-49db-89c9-100cd61cd28a: Answer = A
# 🔎 ID 75316e95-88f4-4fef-83b9-dde0aa52889a: Answer = A
# 🔎 ID bcca13bc-2675-4645-82cc-7e4c412ed294: Answer =
# 🔎 ID ff5b5d2e-5fa1-4709-a9a7-681e4d4585bd: Answer = C
# 🔎 ID d7a45917-d0f9-476e-912d-ebc5af9333a1: Answer = B
# 🔎 ID e625dbc8-f448-4c53-9a78-6c3f351b49c3: Answer =
# 🔎 ID 9bea42e5-3c21-46dc-93f7-0017f382f7cf: Answer = Rise
# 🔎 ID 0925a4d7-8546-46a8-834f-20f58f16bc99: Answer = A
# 🔎 ID dc0aa42f-569d-4277-8149-b645f3cf9888: Answer = A
# 🔎 ID b9964445-c648-4661-ad85-7e5e4cd0feb4: Answer = Rise
# 🔎 ID a803daca-2cab-4d53-be68-c75fb71da84a: Answer = Fall
# 🔎 ID 1ca64702-d7d7-4a9a-987a-4e58938a3b96: Answer =
# 🔎 ID 6caca908-0f01-43b8-a2f4-674d30d03891: Answer = C
# 🔎 ID 4485f013-35ce-4f02-92a9-ae8299565de5: Answer = C
# 🔎 ID 81747de9-22c1-47e7-a6c2-36116f90d772: Answer = B
# 🔎 ID 5dca8ccf-cfa3-4b2f-943c-0d4a28cadf46: Answer = Fall
# 🔎 ID aa5ad602-ac8c-428f-8d08-c7170638b851: Answer = A
# 🔎 ID e4eb6222-3aeb-4dec-b5ea-3d66ec2223f3: Answer = Rise
# 🔎 ID 864e54f2-c66a-4009-83e7-7c53a817d4a5: Answer = C
# 🔎 ID 9c4775a4-f5ca-49e9-815f-d6491ed0612e: Answer = B
# 🔎 ID 25027061-c540-4c98-b3a2-f3342ab56179: Answer =
# 🔎 ID ee2a16e1-1d47-427c-97ae-ad44162984cb: Answer = A
# 🔎 ID f101430b-bbe2-4803-a5ab-691e6295b1f9: Answer =
# 🔎 ID eb23455d-9d29-4e56-b7c1-383a71e1e4cc: Answer = D
# 🔎 ID b0f3c24c-849e-4de9-896b-a3c0b7baa649: Answer = D
# 🔎 ID f259d90e-7120-4459-a814-a456011fc840: Answer = Fall
# 🔎 ID 52823831-b62d-4a94-89a0-afbce85815ce: Answer = A
# 🔎 ID 9f003d54-1999-4b42-9b85-8b9948ad00d8: Answer = Rise
# 🔎 ID a1c3478a-d9ae-4e50-8feb-6bab95236e70: Answer = D
# 🔎 ID b67007a5-e402-44f3-8310-a03e82aae300: Answer = A
# 🔎 ID 18d090c5-fdb3-4432-bc8f-724484060a34: Answer = A
# 🔎 ID 07b70d56-3738-4458-b9c6-b49dc48b3541: Answer = A
# 🔎 ID 53be4f07-fab4-4536-bc89-044a480d0e67: Answer = B
# 🔎 ID 052dd83c-9e8e-47f3-880d-d89a08c9da5e: Answer = D
# 🔎 ID 60ac44e1-9dab-4480-8329-473b7b6bc58e: Answer = A
# 🔎 ID 686fd450-cef8-49b3-9a3d-fb4a1471ee7b: Answer = C
# 🔎 ID b3879d43-60ad-46c5-930d-5f2296e1311d: Answer =
# 🔎 ID ca9322b9-83ac-445c-b797-0c0491b99411: Answer = A
# 🔎 ID c5d43d55-3a4d-442e-afa9-4b04bf10ea3a: Answer = A
# 🔎 ID e32c85f9-6dca-46fb-bae4-7b1e929e8304: Answer = A
# 🔎 ID 14a8a716-b488-4848-944a-558f54c1e08a: Answer = D
# 🔎 ID 9cd693df-44be-42b3-bd28-1dfb7e8f88ed: Answer = B
# 🔎 ID 11238893-60fd-4b99-82c1-fa612e2c2f05: Answer = B
# 🔎 ID c6c767fc-efd3-4f39-a79f-0aab65ebbac9: Answer = C
# 🔎 ID 63010eac-025c-4be8-bb45-d7b4cbdbea0a: Answer = D
# 🔎 ID 9adea360-0371-4a0a-9d16-fbd6117a95d8: Answer =
# 🔎 ID 99aa42a2-8b0c-498e-9df2-11f3e5050776: Answer = A
# 🔎 ID 8bdaa88e-7426-40cc-8e74-366f75db77a5: Answer = D
# 🔎 ID dda08fd7-6c69-40fb-a50a-d01a72de6ee6: Answer = A
# 🔎 ID ed45ca23-3f20-4662-9dde-afcc3f20b0be: Answer =
# 🔎 ID aa6b1b87-34e3-4b67-9fbc-a55a6b2af6a6: Answer = D
# 🔎 ID d9825631-a11e-463b-988f-4e070213f92b: Answer =
# 🔎 ID 8fafdfe8-7ef5-45c1-8283-c9d94915d04d: Answer = A
# 🔎 ID 54e87d21-d3ad-4dab-bb41-563eeb95750b: Answer = D
# 🔎 ID 29efb2ab-4920-4cb8-bae7-6a12f0c0b6b0: Answer =
# 🔎 ID 9366d493-bebe-4bfc-8fd6-1dea83d09bb1: Answer =
# 🔎 ID 43870ef5-80b7-455e-b18d-a5060cfc42fd: Answer = A
# 🔎 ID 84136d86-4cb4-4723-8d85-0a2bc9d06d47: Answer = Rise
# 🔎 ID 9848b932-bf14-47ed-892d-839fbb4c9b29: Answer = Fall
# 🔎 ID 3118667a-9de4-4d6b-a833-0aa98ef26c12: Answer = D
# 🔎 ID ebd5d7c2-3153-4e06-afca-71fed1f24c34: Answer = B
# 🔎 ID 465b59b5-1a3a-48dd-be68-e3f4caf6c72a: Answer =
# 🔎 ID 806692d1-f246-4d9d-a294-f2bcae550c86: Answer = Fall
# 🔎 ID c6cda2fe-3e0a-49b3-9e7d-fdffa0942258: Answer = A
# 🔎 ID c0f8b091-95aa-4ac9-b08f-f812a5f7b5f8: Answer = B
# 🔎 ID 1a87c3d0-83f0-405a-9076-82aad4ca5ae6: Answer = B
# 🔎 ID ec7802de-94fd-46f9-8c05-eb4644465131: Answer = D
# 🔎 ID 458050dc-92aa-4861-82c1-442069f8b6ff: Answer = D
# 🔎 ID 88246405-aff7-4cdd-8e4e-c321511a3995: Answer = Rise
# 🔎 ID 8ecfce58-561a-4b7f-982f-af4407174937: Answer = A
# 🔎 ID 6861f3dc-eeb5-4fb5-a697-9bd290b21439: Answer = A
# 🔎 ID e696199c-f2b7-47a0-a6eb-1a2f65ecac4d: Answer = B
# 🔎 ID 4188098a-676e-41bf-956d-e9769d45553d: Answer = A
# 🔎 ID 6bfb0c4b-8464-4bfb-bc96-689624fd767e: Answer = D
# 🔎 ID 071c7d5b-3923-4000-bdca-72516b91ba78: Answer =
# 🔎 ID 78b14426-e0da-4c34-9db7-ea89abd93250: Answer = D
# 🔎 ID 4dfb6b69-3510-4d68-83df-f98644f30e88: Answer = D
# 🔎 ID 1fa8c1fa-52e0-4280-a4e0-3356241163b8: Answer = A
# 🔎 ID 3dc8a9b5-e2ce-4273-a936-28141c339dc5: Answer = D
# 🔎 ID 82fc1ce2-22da-40e7-ad5f-a1938ee9e1b5: Answer = D
# 🔎 ID fca565b9-8a05-484f-8565-bca3cab90f6e: Answer = Fall
# 🔎 ID 023b60af-943e-4ab4-813d-e85609421fa3: Answer = B
# 🔎 ID 0b6561ca-ccb3-4634-8eae-7e538d77b4bc: Answer = C
# 🔎 ID 3b991e02-2162-42e6-83be-d9d80f3084eb: Answer = D
# 🔎 ID df0f32d8-8ee3-4551-a5b1-4d83347713e9: Answer = A
# 🔎 ID 1460c369-2282-432d-a63a-e72033a84551: Answer = B
# 🔎 ID fa9e0aa3-7557-4a63-9c28-644aa7e03cd6: Answer = B
# 🔎 ID 9980f285-fe19-48ab-bed1-0db8a38025b6: Answer = B
# 🔎 ID 71b5779f-1ad1-470e-86f4-1132894c8828: Answer = A
# 🔎 ID 5d849e44-64c9-4a47-a9ff-f0fd0fbf14fa: Answer = B
# 🔎 ID 29f259c6-0df5-4aba-ab2e-538b712bd2ff: Answer = A
# 🔎 ID c7ee7235-858c-48d4-ad88-2b2a80bce290: Answer = D
# 🔎 ID e6d8e952-6600-42d1-9c0d-6435b38c330b: Answer = D
# 🔎 ID b9a40068-74c2-4dd6-911d-0072d9a7477d: Answer = A
# 🔎 ID 58235cae-5b0f-4f68-b8ef-d04e9ff12633: Answer =
# 🔎 ID 59409dd7-7f7b-4d99-8ec8-6813fc4b1892: Answer =
# 🔎 ID 56ce74fa-f233-47b5-8c14-49cc5d9cc604: Answer = D
# 🔎 ID 7477f674-71c1-4ea9-8982-9b9e6ffce1f7: Answer = C
# 🔎 ID 13ab2783-a3b1-4e87-b3f5-a124faa3edf3: Answer = C
# 🔎 ID 93c60e28-c5d2-46f3-8322-c01ed956d2f0: Answer = B
# 🔎 ID 147c934a-8ec7-4fb7-93a4-dadf8450e625: Answer = C
# 🔎 ID 065f5386-ec07-4a64-81a8-d08c8f941837: Answer = A
# 🔎 ID 293dc56b-21d4-4db0-ba7c-263e56bdf7f3: Answer =
# 🔎 ID 8e8b6b98-cdbd-4569-b976-3b4c00e7f8aa: Answer = A
# 🔎 ID 43e41915-2c2c-4019-8367-594f00343077: Answer = Fall
# 🔎 ID 1067fe05-7e40-4f87-9e7b-447d4decd41b: Answer = B
# 🔎 ID 355ed388-b486-4008-b2b6-4461c2216b09: Answer = A
# 🔎 ID db189b93-24ce-4da8-953a-b06cfa93e418: Answer = D
# 🔎 ID 3e293c72-c589-4454-8061-cbc4d9080150: Answer = A
# 🔎 ID 60c7e672-d84a-4227-8fc3-64c4e707365e: Answer =
# 🔎 ID 7c90451a-3d8b-4ea5-b937-be7e28cfd524: Answer = D
# 🔎 ID 38210e9b-bbf2-499f-801e-b2d48e797e93: Answer = A
# 🔎 ID d2e9c0c3-7ea7-4727-9541-e87543d60453: Answer = A
# 🔎 ID 456118be-4934-4160-b4cc-e9f94393728b: Answer = D
# 🔎 ID cb02d54e-88b7-49a7-b7b7-3a03bb04978c: Answer = B
# 🔎 ID b838cc9c-53c5-477a-a389-6de106bd212c: Answer = A
# 🔎 ID f73b3c90-2f90-43da-b2ca-2f73fe71f190: Answer = Rise
# 🔎 ID 5deeb70f-fb21-4b5a-aa7a-2168f81eb994: Answer = D
# 🔎 ID 253e047e-e341-4cb1-9f88-664c2d54411c: Answer = C
# 🔎 ID a346795e-2436-4ef8-ac48-0c2dd11c957b: Answer = D
# 🔎 ID 722df8de-d854-4657-a98f-92c385611ca0: Answer = D
# 🔎 ID 6ae39294-d3bd-4c56-a3f3-1d5108984bc2: Answer = C
# 🔎 ID 338d4b82-1d20-4cfe-880d-42d9ec4e51db: Answer = A
# 🔎 ID 8808fc1e-4d21-4b42-9494-20d0bf9007f8: Answer = A
# 🔎 ID e79a84af-d13a-4dd3-8c21-aeca796fc890: Answer =
# 🔎 ID 6ce49e4c-8ed4-40db-957b-35343809b8d2: Answer = A
# 🔎 ID 23be0f34-6a7e-42fb-b8ce-59c596060c46: Answer = B
# 🔎 ID 09980997-95f6-4ad8-b06c-40ca953a666a: Answer = C
# 🔎 ID d0c2306f-91d1-49dd-8411-d376234657a2: Answer = B
# 🔎 ID b430bd91-f920-47da-b6d7-82bc3fa3eb67: Answer = C
# 🔎 ID adb6cc13-a9e3-4236-9eea-c1378b427915: Answer =
# 🔎 ID 8230bd9c-6ac4-4e55-9182-8c9235774720: Answer = A
# 🔎 ID e7269468-b899-4064-a595-077abace12e6: Answer = A
# 🔎 ID 2b5d03b0-9dd7-478f-ae05-ccb2185ca527: Answer = C
# 🔎 ID 9e85181c-f3bb-4c91-a13b-6a9d634f2b83: Answer = B
# 🔎 ID b43b9a7d-4e8a-4039-a07b-88c5fe9f12f3: Answer = B
# 🔎 ID d8908bba-e894-4424-be2f-21cf1af08c8f: Answer = B
# 🔎 ID 6c9b6321-9d7a-4988-a0c3-a7c7fdb04def: Answer =
# 🔎 ID 8196e74a-c2e2-4a47-96d1-e8028b22fb34: Answer = Fall
# 🔎 ID 31f069b4-77a6-40d2-a898-00e6356292d7: Answer = A
# 🔎 ID 94dfff32-1961-47df-afe2-cd844f951b9d: Answer = D
# 🔎 ID 83364184-384d-4589-8473-be9d76dee9a6: Answer = Rise
# 🔎 ID 6348a790-e8a3-4d1c-bfd3-d2e838643e4d: Answer = D
# 🔎 ID 95de54ef-9cc2-4f5e-afc6-d0fd6cf9635e: Answer =
# 🔎 ID 1ce82d55-0c6d-49ee-a6df-9d8cd46cc635: Answer = B
# 🔎 ID 1689573b-58d3-40e6-a1fc-4289c9e22d3b: Answer = D
# 🔎 ID 6b029f48-10bf-45e3-9997-c9743f49f70f: Answer = B
# 🔎 ID db792cce-5b60-47dc-b82a-d5198d13c22a: Answer =
# 🔎 ID 816d8c21-0da9-4591-b946-5ad51bd1b1c4: Answer = A
# 🔎 ID fb77617c-0a7c-4681-a871-4e54345f469c: Answer = C
# 🔎 ID a3189073-1452-4ce7-b434-77f853a1ac3e: Answer = C
# 🔎 ID 8db1e38e-dc8d-4e3b-a520-c7f3e6ad4ddd: Answer = Fall
# 🔎 ID 4a222fdc-4184-4ba5-a699-49ed51af1b13: Answer = B
# 🔎 ID 07bf0528-a3a2-43e4-86c9-8c5040ab8da5: Answer = B
# 🔎 ID a8373859-c4c0-4367-98c4-b8ecc6d06a88: Answer = D
# 🔎 ID 55195adb-c94f-433b-9525-009a86a4b325: Answer = A
# 🔎 ID 966804b1-9236-4096-8796-feadd7108ad8: Answer = D
# 🔎 ID 459f930d-b8ee-4486-815d-fb803e4881bd: Answer = A
# 🔎 ID b3c507af-8777-46ad-ac6f-beaea5c54f88: Answer = A
# 🔎 ID 4215becd-afd1-46ea-8aef-6ee6482252a5: Answer = A
# 🔎 ID c67c87fb-9e34-49ce-bbfd-afb7776a30e7: Answer = D
# 🔎 ID 897a2916-5b68-487c-8d9e-c370e6f91211: Answer = A
# 🔎 ID 9270c9fe-fbe5-49cf-bc5e-0e3a37e8bc75: Answer = A
# 🔎 ID b4412e44-7ed6-4b74-9c0b-25a786d12279: Answer = C
# 🔎 ID 858a3fcf-5e8b-4913-b997-b6889e5b3b3d: Answer = Rise
# 🔎 ID c5b9808c-deac-42a2-bbe3-7d4ad401dcbc: Answer = A
# 🔎 ID 24905917-f933-4939-bd5e-12eb5b2d7718: Answer = B
# 🔎 ID 3f608174-ab75-4f7b-8e94-b74f6cdd629e: Answer = C
# 🔎 ID 7860aeb7-ea22-435f-b2fc-a93d3e8f2d33: Answer = B
# 🔎 ID 99902471-b658-4060-ad15-49b08849aaf5: Answer =
# 🔎 ID d3774c70-fe80-48c2-b976-24880f87b169: Answer = C
# 🔎 ID 80d4a639-8514-433c-9113-20c70e403580: Answer = C
# 🔎 ID f79a468a-53f9-43a9-bcfa-47e90aab5031: Answer = Rise
# 🔎 ID ad19fb4b-f1a6-4ae8-8d5b-f4768623f3e7: Answer =
# 🔎 ID a70749e2-40b4-4316-be72-caf9c325493e: Answer = Rise
# 🔎 ID d66b72dc-0f7f-4186-a9a3-cd1aba5fb642: Answer = B
# 🔎 ID e7e52252-5af8-4f3d-9ec7-24fc7bbb16a1: Answer = B
# 🔎 ID cef535a9-3a43-401e-bf11-67a1ec014ef1: Answer = A
# 🔎 ID 84e452ca-fab9-4fbc-89b9-43261176d916: Answer = C
# 🔎 ID 57df6d51-9629-4fb6-a106-70546e538952: Answer = A
# 🔎 ID 95b112eb-9f3e-4008-81e3-9c7b9e8d1db6: Answer = A
# 🔎 ID 2a316ff6-5c01-440b-b8bb-c296c5416915: Answer = A
# 🔎 ID 1106248e-94f3-493d-b7b3-c671ccdd7a21: Answer = B
# 🔎 ID ae7107cc-6eee-482a-ae1a-5a454809640b: Answer = Rise
# 🔎 ID ed0074a8-aa7c-4499-8356-4720a17eb6fb: Answer =
# 🔎 ID 49f4b9c2-c4fb-4c96-a937-cdd77e53548a: Answer = A
# 🔎 ID 88707356-9edf-468b-a8bf-7eb76967ccfd: Answer = A
# 🔎 ID be3cbe2e-d8fd-413d-b635-6a426c786214: Answer = B
# 🔎 ID 8e634d1a-a45c-43af-bf11-8be9beab00a8: Answer = A
# 🔎 ID 19df2303-341b-4c65-90a1-d27d54351713: Answer =
# 🔎 ID c41674ab-5e59-4254-93b6-2fd4b8749a30: Answer =
# 🔎 ID 0dc31414-ec59-41cc-9cdc-a6530a760c61: Answer = Rise
# 🔎 ID 7e51508e-e643-48b3-8ae5-74dc54542194: Answer = B
# 🔎 ID 5fd3d834-beb7-4f3b-98f9-ad5619e956ba: Answer = D
# 🔎 ID d2bbdcb6-9c30-4a0d-aa3d-8b0ece79223c: Answer = B
# 🔎 ID 2ab9b7e1-6a3c-4a7d-acc1-1c9871553dc1: Answer = A
# 🔎 ID 371af364-7d77-47ac-86b8-2140df86f164: Answer = B
# 🔎 ID 1ca68c5f-e294-45fb-b94d-05c8289695e9: Answer =
# 🔎 ID fb908d08-d788-4f38-95fe-d74a693429c8: Answer =
# 🔎 ID 6cef7dd5-41b8-46d3-85cd-5d972e019908: Answer = B
# 🔎 ID 6bea53e8-a147-41a8-9921-71a4f922ac8b: Answer = B
# 🔎 ID 06047e07-d4e1-4805-aa71-2d64624399e9: Answer = A
# 🔎 ID 3911a620-1ce1-4031-bb7b-5fcce34abead: Answer = A
# 🔎 ID 458c1dd4-0075-4b2c-8abf-79dfced7926e: Answer = A
# 🔎 ID f127f64a-4712-4870-b716-1ac81ae79922: Answer = B
# 🔎 ID 786ba23c-ee38-491b-9355-4a55a5d740f4: Answer = B
# 🔎 ID 0feddd0f-60c9-4bad-83d4-2a7cced2bea4: Answer = D
# 🔎 ID 8c515324-260c-42a4-aa34-416cb5876f3e: Answer = C
# 🔎 ID b88339e8-beb6-4605-b2a2-9f4e15617447: Answer =
# 🔎 ID 6fc87f4e-0638-4951-a315-6e7845ba037c: Answer =
# 🔎 ID cfd09c2d-6f7c-431f-9fb4-074a7bcb8179: Answer = C
# 🔎 ID 3cfa6d3d-fb56-44dd-a212-e6560370fc58: Answer = C
# 🔎 ID e87ec60a-8bfa-4253-a951-7a30d23d0cc1: Answer = D
# 🔎 ID 4b8d1ae4-c952-4751-8b59-3ca65122defc: Answer =
# 🔎 ID c464c03a-0b88-4eea-9afb-40c502d65b8b: Answer = Rise
# 🔎 ID 3b97d534-fd53-4825-bacd-b40590d92531: Answer =
# 🔎 ID 9585af54-a3c1-4ace-b532-0f200fb804f0: Answer = C
# 🔎 ID cab56075-c7ea-4456-9074-f734c41d44b9: Answer = Rise
# 🔎 ID e93efb85-ea9b-47d9-8293-97401e2c9b51: Answer = D
# 🔎 ID 3a598f2b-1b91-4b46-a036-f6dabf8d9d99: Answer = A
# 🔎 ID aeee0e6c-aef8-4276-99f6-daf21aa17922: Answer = B
# 🔎 ID a8f66015-04c5-4d66-845e-5175725ee1ef: Answer = A
# 🔎 ID b98d3b89-6a9a-4304-8a2c-30e19c2776a7: Answer = A
# 🔎 ID 33ed0975-00a3-448d-b733-270afd6bf0d1: Answer = B
# 🔎 ID e0f0fa14-77ba-4060-8139-605a7b05c1d2: Answer = Rise
# 🔎 ID 5b0ed38d-5eb1-45a5-838d-51f5fdb8d118: Answer = C
# 🔎 ID f7a01d49-e8d8-4886-8195-c2c3bcebeb76: Answer = C
# 🔎 ID dcc0ac85-63b0-4f7b-acb9-ae1cd72b859d: Answer = C
# 🔎 ID 643e3e5f-3d27-4dc5-b98e-e6abb8429278: Answer = B
# 🔎 ID 1450cdb2-6dbc-40df-b8f0-13917af9f36c: Answer = D
# 🔎 ID b52ec923-274c-4902-9128-2ce3d2b29865: Answer = A
# 🔎 ID 0c424fc8-f522-4926-99a1-dae0f5982ba1: Answer = A
# 🔎 ID 3c302b63-0d15-43ff-b731-e94b70574213: Answer =
# 🔎 ID 2488d489-71b4-46a8-aa64-268b8073f675: Answer =
# 🔎 ID 9dc441e5-ca12-40b3-b76e-e03bdbd0e5fd: Answer = A
# 🔎 ID 1f594eee-5b89-44a9-b853-5fe5920db404: Answer = C
# 🔎 ID 64fc227a-9620-487d-a899-e797e9c08000: Answer =
# 🔎 ID ca3ff832-288a-4bd0-8e78-2bd8f8380d6a: Answer = B
# 🔎 ID dd570589-21de-48d3-9f3a-461396712ddd: Answer = Rise
# 🔎 ID 254c3da2-a07b-4884-9191-2ff6070a25e1: Answer = C
# 🔎 ID a3b35677-0356-4925-ad0a-25b6cd19836b: Answer = B
# 🔎 ID 4319211c-49f4-4af4-9ba8-0854ba3a8c1e: Answer =
# 🔎 ID 66d40b17-9f45-43cd-8492-6712436dab30: Answer = D
# 🔎 ID 8e52131d-cf4d-4c6b-95d1-2c8fa03b5f04: Answer = Fall
# 🔎 ID dc0952ef-3be8-4255-a4d4-7f80afd639a5: Answer = C
# 🔎 ID ec9a6f77-87b5-40c8-901d-e39f3a5c0881: Answer =
# 🔎 ID 5aa996c4-a335-4aa3-94d2-15041aafd672: Answer = C
# 🔎 ID fb06a121-136e-4ed2-ba10-dc8fea7ea6b8: Answer = D
# 🔎 ID 31503cdb-78dc-4018-b849-e1d08f781677: Answer = D
# 🔎 ID 7d0b95b3-de8c-4582-a682-df9aa60f6322: Answer = C
# 🔎 ID 4c101d4a-b3f2-4eb0-803c-cf02f0017e71: Answer =
# 🔎 ID 12ad4556-3267-4fbb-be00-64e941aafd8c: Answer = A
# 🔎 ID 88b88739-d285-4fdc-8b0a-1bdb8802f21c: Answer = D
# 🔎 ID a2a4061c-a3ad-4f10-8c18-f2d259976091: Answer = B
# 🔎 ID 386c1cc6-d814-404e-a8e2-5300f3081681: Answer = Rise
# 🔎 ID 71b5d40c-cf25-4ab4-affa-02c3e02f32fb: Answer =
# 🔎 ID 14e28099-4c6d-4d92-b328-93bf48621e85: Answer = B
# 🔎 ID d3e6b2fb-e986-4b59-896f-ec1ecf640f37: Answer = Rise
# 🔎 ID 2bc03162-8c5c-472c-a8b8-162503e11cd3: Answer = B
# 🔎 ID d619939c-2979-4e5b-9893-90bcfc765325: Answer = Rise
# 🔎 ID 04f1c133-3e8c-4e5b-b6f0-c946e2a8b5b3: Answer = B
# 🔎 ID e3b362da-51be-4b04-a710-675c1e94f8d1: Answer = A
# 🔎 ID d0e16feb-4980-4212-86d6-7b54290fbd71: Answer = Rise
# 🔎 ID 28addcbb-457a-45d3-b5f6-49dac8da9be1: Answer = C
# 🔎 ID 46aff7ab-ea35-42c6-a546-c37cf2505770: Answer = A
# 🔎 ID ba9430e9-4be7-459a-9c67-818a4a7cecb8: Answer = Rise
# 🔎 ID c107268e-a5fa-414b-b736-512c637dd55e: Answer = D
# 🔎 ID 8dea0c45-9a8a-4de7-9ea6-1788794cda27: Answer = A
# 🔎 ID 1b15774b-156c-4dbc-9b11-32c464d2804d: Answer = A
# 🔎 ID ddc6557a-681d-42a3-9918-5f3cd0c05e41: Answer =
# 🔎 ID 695ef96b-b129-4a74-8a6b-10fee1974c6f: Answer = B
# 🔎 ID 3f6d41be-ec66-492d-95df-e9d17d2aa03c: Answer = A
# 🔎 ID d64d69a5-9dc5-4ac8-bd6e-0d2266525e0c: Answer = A
# 🔎 ID 3ebf2e5d-c86c-4fcd-a511-8e4139b38d30: Answer = B
# 🔎 ID 1685510f-f139-4b36-bafa-0c641e4f2411: Answer = Rise
# 🔎 ID 4fc850d7-7c29-4ca3-9614-426e62364660: Answer =
# 🔎 ID 0d4519c9-45dc-4acd-8562-eaff2e51507c: Answer = Rise
# 🔎 ID 40d4e77f-1899-4588-a50e-622c1f5b98cf: Answer = A
# 🔎 ID e616a96f-30ec-428e-ad4f-859339e280e9: Answer = Rise
# 🔎 ID 463feaf7-7a05-475a-9e0b-4c68024dc9f6: Answer = Rise
# 🔎 ID c5ff368c-6852-461b-a437-92aa9dea33c8: Answer = Rise
# 🔎 ID b545cd6a-2096-4fe9-b087-6ebda6fcad60: Answer = Fall
# 🔎 ID 153b7296-aeee-427c-a7f2-f34b71157396: Answer = A
# 🔎 ID 07d4daaf-9adc-48ed-ab6f-4f2f633ef2df: Answer = Rise
# 🔎 ID 1c44725a-dc9a-4f71-b818-4c762bba4522: Answer = C
# 🔎 ID 52279b47-f0cd-41a2-9257-1d15b8c4a45d: Answer =
# 🔎 ID a25860fa-d0bb-406a-aa61-8ee03e0d48fc: Answer = C
# 🔎 ID c60c2dbc-647a-41b3-8a31-9e5e45fbe324: Answer = A
# 🔎 ID 8c4fdc62-8332-4ce2-8d9b-c81b4ead1e57: Answer =
# 🔎 ID 700cd637-5d55-4497-8b87-e98fff71664d: Answer = B
# 🔎 ID e4295489-337b-427b-a1cb-c89238008fe5: Answer = A
# 🔎 ID e032394c-695a-4180-9830-7c67bcd71d68: Answer =
# 🔎 ID a76352ca-ef66-42a0-99ab-e780ad82dcd7: Answer = B
# 🔎 ID 3e0fd2d2-782e-4364-bd5c-7b051da383c4: Answer =
# 🔎 ID 005927f1-3078-4a57-a10e-cf378130feeb: Answer = C
# 🔎 ID f060ff08-2355-4f29-976a-3db151f3aa47: Answer = D
# 🔎 ID 34aa582a-467e-4fa6-8d3f-0b1d45538bf9: Answer = Fall
# 🔎 ID 53af599d-bf99-494a-92ab-74318de79038: Answer =
# 🔎 ID e48f8afd-ae94-4425-aad8-da097689d86d: Answer = B
# 🔎 ID 6f27ae92-7a2e-44e6-adcb-f4faf42157a7: Answer = B
# 🔎 ID 63d036ce-8259-4f6a-b7f6-8a87203ba95a: Answer =
# 🔎 ID 3f2f8189-22ec-4ec9-a7e8-cd68ef2695b4: Answer = D
# 🔎 ID 129cf14d-1dde-43f2-8a86-9090aa068e01: Answer = B
# 🔎 ID 38a9a6e1-b41e-4ba5-b3fe-a09a0495f50b: Answer = D
# 🔎 ID 136d6cb5-3ff7-4fa0-b08b-eb16430e1338: Answer = D
# 🔎 ID c7236320-d409-4439-aced-5862d8c862c4: Answer =
# 🔎 ID b2428cc5-60cd-418c-a97f-d369474c3c58: Answer = Fall
# 🔎 ID 40e38322-4743-4704-8e74-1691d84e38f0: Answer = C
# 🔎 ID 07829774-424a-4e51-a3c7-5e4d0773a7ad: Answer = Rise
# 🔎 ID 87967630-ab73-41c1-8a94-8e7eb7724b31: Answer =
# 🔎 ID 12b05ba3-dbbb-412e-a73c-7aa32584aa68: Answer = A
# 🔎 ID f32a729b-40fa-40ca-9e11-17c1d327d0a6: Answer = C
# 🔎 ID 9faa7719-7845-4abc-bac7-2c22b693ee80: Answer = Rise
# 🔎 ID d07f32a4-0413-4728-ad6d-0c55701ac699: Answer = Fall
# 🔎 ID a4739fdc-9266-4f1d-93dd-cc8179799ea5: Answer =
# 🔎 ID c1669ae8-3ed4-4b9a-b9f1-f25deeb29653: Answer = D
# 🔎 ID 34746e29-01c9-4780-bcbe-1254ba8350cf: Answer =
# 🔎 ID 0d8225f8-7ccb-4c2f-921c-4117390e701e: Answer = B
# 🔎 ID 4e994910-ea43-4ca1-a1c2-ce2dcb3e4314: Answer = A
# 🔎 ID 16f75c69-e126-4a9b-922a-8aa94e1cd64e: Answer = D
# 🔎 ID 6d494a75-722d-474f-935b-7e662b79368b: Answer = B
# 🔎 ID 15e4a5a0-4bee-4fc0-bc2f-8fdcffa12b26: Answer = Rise
# 🔎 ID ad3058ea-94a6-4d16-8c05-03f94ebc0727: Answer = D
# 🔎 ID b1b5c45f-6b72-47e0-a515-115acd6a61f5: Answer = A
# 🔎 ID 254d405c-4eb5-404c-8730-71f32a550428: Answer = A
# 🔎 ID 2a3f5fb7-531d-40d9-a9f9-de5af571da86: Answer = A
# 🔎 ID b1dcb920-1bc9-49df-9ad1-082088604664: Answer = A
# 🔎 ID 970123cb-1cf9-4433-9054-4153e2315903: Answer = D
# 🔎 ID be58058f-76d3-4938-b148-e20b0181a772: Answer = A
# 🔎 ID d9235457-8f43-4c03-9cb1-d94d760e04af: Answer = Rise
# 🔎 ID 2baca139-50ff-4573-a0b6-54745cca9503: Answer = B
# 🔎 ID ca81f25d-37fe-4fce-9a71-b777a6a9e7eb: Answer = A
# 🔎 ID 3aa9f39d-a994-4a4b-8b3f-a349abe7b2a8: Answer =
# 🔎 ID 971d2b9a-2cfd-433c-90b3-085cbc01699e: Answer = C
# 🔎 ID 3dbbff27-a761-4cb9-8c79-a33824dceeed: Answer = A
# 🔎 ID 0b357a06-316f-43a5-8f61-237c99104284: Answer = C
# 🔎 ID f910043a-f0c9-4522-9171-05310e3590fe: Answer = B
# 🔎 ID 34cc4a28-d945-452a-b324-c8d3d50660b5: Answer =
# 🔎 ID a6227157-d933-4185-b184-85d01b9de996: Answer = Fall
# 🔎 ID a8c57a8c-74d9-4e15-826b-bee316b666df: Answer = D
# 🔎 ID e6c7a460-5ffa-4408-8004-51c27ac32cc0: Answer = A
# 🔎 ID e33d3c08-acbc-423f-8f26-9b526411bb04: Answer = Fall
# 🔎 ID 581ef551-a8a5-411a-a0ec-ca61af3c5fc9: Answer = D
# 🔎 ID c2de2651-f748-49b6-80d7-3a67cb25ea89: Answer = B
# 🔎 ID 41ea0e3d-e4b9-47c7-ad10-9b8972a64930: Answer = D
# 🔎 ID 82c4411f-3ad6-4823-83e6-f1403bb72ae7: Answer = C
# 🔎 ID 266fbaae-524e-441b-ae30-86057cf1aae9: Answer = B
# 🔎 ID 29edf2dc-eae5-45e9-b3e4-154a5ab4ca46: Answer = D
# 🔎 ID afb73235-0524-4684-b4b9-5ac359f0d6ca: Answer = A
# 🔎 ID 3dc96b06-0c12-4d71-84b2-566bf519f7b0: Answer = Rise
# 🔎 ID 4f889cac-74d7-4a9a-93c1-68fbd8a864ba: Answer = B
# 🔎 ID 008c77f3-e985-4ccb-9321-3187a3e99222: Answer = B
# 🔎 ID c949e2db-5912-4c08-8fb7-50b9ef2ffe30: Answer = B
# 🔎 ID cde3aba2-c5a4-47ec-835c-92f9b062c4af: Answer =
# 🔎 ID 81503475-cb97-4768-ba2b-c0721113d2e5: Answer = B
# 🔎 ID 9c306032-9f09-4cf6-8443-5c014dbeb745: Answer = A
# 🔎 ID 921755e2-4930-4b0a-b02b-d241eb2467de: Answer = D
# 🔎 ID fbb4a405-0a85-4516-a030-c04e29cea187: Answer = B
# 🔎 ID b5536812-111a-45e8-9d93-e852bc9ba013: Answer = Rise
# 🔎 ID 3c92dbca-7863-437f-b8fa-f5e4acc2a553: Answer =
# 🔎 ID 750940c9-5a1b-47cb-bf72-3bdabd156cda: Answer = Rise
# 🔎 ID 4f18cd0e-9b48-4b01-a0bc-738414d9840b: Answer = B
# 🔎 ID edc10bc9-f5fa-47ed-a805-9ed7df5bd2c5: Answer = Rise
# 🔎 ID a04f5fef-a7f7-407f-b968-8fa954fa4c5c: Answer =
# 🔎 ID 4e12db0a-af42-40da-bd45-b62df8aa7130: Answer = Rise
# 🔎 ID 972fd1a2-3409-4698-9437-9a1fb88f9890: Answer = Fall
# 🔎 ID 9ec4a788-8c4f-41c7-9773-4bf02a668bf8: Answer = C
# 🔎 ID b56a9051-bd7a-4bf0-b26d-df040dbe75aa: Answer =
# 🔎 ID 32c61371-f227-4ef6-982f-bcdd66b9ed21: Answer = A
# 🔎 ID 105c105c-93a9-40e3-bb48-1d9928899baf: Answer = Fall
# 🔎 ID b48f9832-89c0-46c9-88f7-035ceb674f36: Answer = B
# 🔎 ID 70da30ff-4e27-4281-a2f2-9b8644241913: Answer = D
# 🔎 ID e8f95b11-b029-495f-bc74-243ad5748cc7: Answer = A
# 🔎 ID 7ebbab46-8177-4b2e-ad49-bb12a3b8ef41: Answer = C
# 🔎 ID 17fa2b22-dd8a-4330-94df-089502a67628: Answer = C
# 🔎 ID 46253b6e-aa2c-43b7-a338-b76129272926: Answer = D
# 🔎 ID aef9500b-437d-45ec-9fac-d3ede6a67189: Answer = A
# 🔎 ID 574ac3f7-1c65-4854-a598-fa4462f572f8: Answer = B
# 🔎 ID b959872e-6ed1-4401-8ecf-5a5ce5283aa8: Answer = Fall
# 🔎 ID 76ea0494-7ef4-4e0e-a503-0c196fa67968: Answer = A
# 🔎 ID 8bb9ee0b-cc49-440f-a822-766ba569f588: Answer =
# 🔎 ID ed95455d-d342-4f89-a736-5ad23f944b05: Answer = A
# 🔎 ID e8d4b45e-3b21-4e47-b0dd-5e4d129e427f: Answer =
# 🔎 ID 242f4087-26e5-4b07-a0b6-c33cd7797db3: Answer = D
# 🔎 ID c4db02ee-7dcc-44fe-a5ad-25088afe0887: Answer =
# 🔎 ID d1304af3-591e-4a6b-8c9c-6cbb2e8d053f: Answer = C
# 🔎 ID e022589b-822a-4c5c-bad8-b96ed28854a2: Answer = C
# 🔎 ID d344d958-8978-4d50-90e9-b3ff819d8093: Answer = A
# 🔎 ID e12892b3-a019-419b-b0b7-06227e17fa59: Answer = A
# 🔎 ID 7202a257-7729-40f1-912b-bab5f1879997: Answer =
# 🔎 ID 082bf69b-b784-4160-b76d-6a451bc5cd99: Answer =
# 🔎 ID acea7f10-160b-467e-b0af-dc1566b6c576: Answer = C
# 🔎 ID a02f6f6f-246a-4f9e-9823-d347873a2350: Answer = Rise
# 🔎 ID 0cb5c124-7942-4b65-9c1d-d27a44a71d39: Answer = A
# 🔎 ID 5e7d5fc8-603f-4b26-947f-bcc8821cfee8: Answer = A
# 🔎 ID 46c930ec-ef36-4f83-a0a2-b24da54ce9a6: Answer = C
# 🔎 ID d391afc8-0aa0-4ad3-b830-bfe54417e935: Answer = D
# 🔎 ID 87e510c9-5916-467b-9bf1-af3722da8359: Answer =
# 🔎 ID daeac634-ff52-4960-9dcc-e5d246b14660: Answer = A
# 🔎 ID 75284b05-0429-494c-9964-ef2ea92d7e5f: Answer = A
# 🔎 ID 90216f7e-ad76-4919-9987-946569349fa6: Answer = B
# 🔎 ID d59a6353-8a9a-4187-8da6-2c1f96d9ecea: Answer =
# 🔎 ID cd5e38c4-a78a-4424-af72-320b5ad83068: Answer = B
# 🔎 ID a299e97c-a12a-403f-b305-c65842bf2f4c: Answer = C
# 🔎 ID 2b12322b-fa78-443b-949a-a552a2aa23a3: Answer = C
# 🔎 ID 9c0d507a-f862-46e5-bffb-56e2e9138e71: Answer =
# 🔎 ID 02bd3372-6983-4bdf-81ab-d61374619e9b: Answer = A
# 🔎 ID 4752d3ed-9906-4091-babe-9d143e5212ae: Answer = Rise
# 🔎 ID 7632c975-e9bc-425c-9a15-55b91dd98d9e: Answer =
# 🔎 ID 0eee83e1-25ec-41d0-923f-278ebaccb325: Answer = A
# 🔎 ID 5d9ae971-d750-4d66-95fe-bf4c15f9b3a1: Answer = B
# 🔎 ID f0421ea0-3e86-4f27-904c-1493e91c41b9: Answer = B
# 🔎 ID c4c7f029-4d9c-46dc-b49b-d07d26b062da: Answer = C
# 🔎 ID 0257e1b2-4572-4ac8-8527-27d741f9f484: Answer =
# 🔎 ID 33b26650-1f61-4fc3-b261-40f81a6d4076: Answer =
# 🔎 ID e8b1994e-bbfe-49ad-b8db-2a7b5c7b4590: Answer = Rise
# 🔎 ID 75363c0f-d203-450c-af94-57c553d14a1b: Answer = B
# 🔎 ID 4f9958a4-1dc3-45eb-aa77-09b8500d0559: Answer = B
# 🔎 ID df1de509-6d23-476e-8365-a829760cfef4: Answer = B
# 🔎 ID 467c2541-c4c6-479f-8fac-ddca1554d03a: Answer = Rise
# 🔎 ID cc8abe39-4737-42ab-b16d-245b1c663e7e: Answer = Rise
# 🔎 ID 24d73e5a-f386-4500-ac9d-60cee140a3bb: Answer =
# 🔎 ID 6f1a923f-5d90-4ca7-9dfb-fbad1a2eec4d: Answer = A
# 🔎 ID f541dacc-5783-4f8e-8273-f78a1a04f5c1: Answer = Fall
# 🔎 ID b0d46fd1-b6c5-45a6-84ab-12f6cfb6e9d6: Answer = D
# 🔎 ID f7fb61f4-aef9-4c11-8f3a-88016724fdcf: Answer = B
# 🔎 ID 9caea094-a7bf-463b-b625-939c4eb60def: Answer = A
# 🔎 ID ee23b70c-8c2a-40ae-9e5a-1f4189bda15a: Answer =
# 🔎 ID 28b6405d-ec3c-49c3-8df9-73b89a328091: Answer = C
# 🔎 ID 4df3ac61-2eef-4ef4-a1ba-9e06ef5c7e8c: Answer = B
# 🔎 ID 60ea11d0-90f1-4329-a08d-d1988fe8ab2a: Answer = C
# 🔎 ID 191f0cef-8eed-44c7-a465-ae4582637ff7: Answer = B
# 🔎 ID 18329450-5b58-474e-b9f6-1ff2621a3544: Answer = D
# 🔎 ID 35577239-1e09-43da-a99f-ad4f2a98a995: Answer = B
# 🔎 ID 4bcf475c-4391-4bc7-863c-670c771f8250: Answer = C
# 🔎 ID 056a96ec-6149-4695-8468-3bb33f99219e: Answer = A
# 🔎 ID 794c0de8-809e-46b2-a39a-e2746504de92: Answer =
# 🔎 ID 591311b5-5c34-4a2b-a38b-5a21c95c8892: Answer = Fall
# 🔎 ID a879b47b-2182-431e-8299-24f4e32dfff1: Answer = Fall
# 🔎 ID 6c7d8e07-24d9-40e7-9cec-7b8663308a5e: Answer = Rise
# 🔎 ID a2f4a9a9-8f6d-466f-b2fb-24b03ad299ae: Answer = D
# 🔎 ID 52d45a61-bfe8-4105-ad99-2a90ef336603: Answer = B
# 🔎 ID 3b35b7ee-b3c3-4237-9692-d3cd73ce5c55: Answer =
# 🔎 ID 25e9fbfe-74ed-4799-b31b-c8bce774f7e0: Answer = Rise
# 🔎 ID 692b1495-5a03-4280-bc6d-bd5cfdd61fd0: Answer = D
# 🔎 ID a03e6249-f4e6-4c24-91ab-daa9f02bf9c9: Answer = Rise
# 🔎 ID 68eb9ffa-7ae7-47bc-a83c-da5d1d4277e8: Answer = C
# 🔎 ID 62310ac4-d797-4a81-9746-5ffbe6941f98: Answer = D
# 🔎 ID b6bbd627-c071-4216-80e2-7599fcb87b91: Answer = A
# 🔎 ID 3c178bf3-f48c-4a09-8d8f-116852721480: Answer = C
# 🔎 ID c5dcfef4-b265-4559-9093-44cf4e16c3dd: Answer = C
# 🔎 ID d5bb8d53-69a7-4584-b354-28e5851a544f: Answer = A
# 🔎 ID 417df0cd-10ee-4faa-abb3-9fa87e8b20db: Answer =
# 🔎 ID bc66b7d0-3ac2-49b5-9800-1350b5b142cc: Answer = B
# 🔎 ID a48033fe-2bdf-4356-b08f-dbe5027e29e1: Answer = A
# 🔎 ID 45d1b97e-8f4d-42d5-9082-cd3359ec6cbf: Answer = C
# 🔎 ID 5bd5f68f-90d9-4d8b-b309-78550ef4d69e: Answer = C
# 🔎 ID b91d336b-b9d5-43b6-9d38-5d621c81d117: Answer = B
# 🔎 ID 091be8f8-ba0f-49d7-b936-65d311b2619f: Answer = A
# 🔎 ID 29c5ad39-9344-4be0-bed6-5590131da2be: Answer = Rise
# 🔎 ID 50524206-3192-4f3e-a3f4-42aace66c76d: Answer = A
# 🔎 ID 9ee0b342-46fd-49be-b001-411a98e0951e: Answer = Rise
# 🔎 ID 53eb8585-c961-4190-9431-337a01d601bc: Answer = B
# 🔎 ID 753f1ab4-7397-4fcd-9c73-1a1ac44331d8: Answer = C
# 🔎 ID 2fb39ea7-b7ac-4399-8cfe-f9c300b87a78: Answer = D
# 🔎 ID 86df7cf1-7825-45f1-a7e4-9600dcf4eb9b: Answer = B
# 🔎 ID 567759cb-6ddb-4423-a5f5-ecb0a62668e8: Answer =
# 🔎 ID 6ca5d2d3-16d0-4f0b-b911-334874214a0c: Answer = C
# 🔎 ID 100b91ed-1d63-4d85-aa84-51ecc4d21cbe: Answer = A
# 🔎 ID b40ff000-7b52-416c-b438-f75cb81f8794: Answer =
# 🔎 ID 04889cad-d163-42f3-aab6-085574e93266: Answer = A
# 🔎 ID 468934ee-b596-4e39-b990-b16e4171fedc: Answer = Rise
# 🔎 ID a2cf5599-ff05-42be-a0dd-6070b4dfad81: Answer = B
# 🔎 ID 31153345-5888-49ea-8c79-b0d3e3eadba1: Answer = C
# 🔎 ID 0fb13ae9-8b3d-4ac8-8118-fb1af8d7844d: Answer = A
# 🔎 ID cdaacd9d-e065-4b70-afcd-33422852f08b: Answer = A
# 🔎 ID e0165075-52d1-4933-a42c-55db2c7d0cb0: Answer = A
# 🔎 ID 7f79e8b5-5fbb-44dc-bb8b-2aa3c28126a3: Answer = Rise
# 🔎 ID 63ad4a41-483c-4fe3-a103-37c63fdcedf7: Answer = B
# 🔎 ID 53a5d44a-144e-4c24-87ed-f8ede2b0d489: Answer = B
# 🔎 ID 2699eaff-d51f-4ccc-8a15-8615d54f7a48: Answer = Rise
# 🔎 ID 4e4756bd-532e-4382-8999-831b09977d1c: Answer = B
# 🔎 ID 81373149-111d-4f41-95b9-5755ec00ff5c: Answer = C
# 🔎 ID 448946ff-f302-4005-9197-5ae7f3fe598d: Answer = A
# 🔎 ID 61b1912e-1895-4bfb-8c9d-6ccc3647d8ff: Answer = C
# 🔎 ID 6d9410cf-37da-4c3e-9db3-3f0e726bc46c: Answer = A
# 🔎 ID 398cfaa2-d91d-4740-8fa7-98cfcac894f6: Answer = C
# 🔎 ID b5421aa0-775e-4517-89ca-9df2d122086b: Answer = B
# 🔎 ID e6803272-4f47-4e8b-b288-db5df245e2f9: Answer = B
# 🔎 ID a2327a53-1119-480d-b99e-026b50f0d7ea: Answer = B
# 🔎 ID 0d118fcd-437c-4d78-8ad9-e9a9bb84f44d: Answer =
# 🔎 ID 66483dd4-ad1e-45dd-b2a7-aeb44063695c: Answer = B
# 🔎 ID c9dd262e-405c-4078-baae-262aa48ddcc8: Answer = C
# 🔎 ID 73c720b5-1101-4790-af52-3366823e1d32: Answer = B
# 🔎 ID 357db18f-d872-416e-a07f-753099853d9c: Answer = A
# 🔎 ID 2d8b1419-1c46-4e83-892a-081fb417de38: Answer = Rise
# 🔎 ID 0ef677d5-2858-407c-9fd5-49d8afbeaaac: Answer = C
#
# 📊 Batch processing finished. Total answers: 499
# ✅ Saved 499 answers to financial-analysis-agent\submission.csv (updated existing entries)
